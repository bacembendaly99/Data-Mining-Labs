# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('result.csv')
df.head(5)
# Out:
#   Key_Dataset  Key_Run  Key_Fold                         Key_Scheme  \
# 0        iris        1         1  weka.classifiers.bayes.NaiveBayes
# 1        iris        1         2  weka.classifiers.bayes.NaiveBayes
# 2        iris        1         3  weka.classifiers.bayes.NaiveBayes
# 3        iris        1         4  weka.classifiers.bayes.NaiveBayes
# 4        iris        1         5  weka.classifiers.bayes.NaiveBayes
#
#   Key_Scheme_options  Key_Scheme_version_ID     Date_time  \
# 0                 ''    5995231201785697655  2.022033e+07
# 1                 ''    5995231201785697655  2.022033e+07
# 2                 ''    5995231201785697655  2.022033e+07
# 3                 ''    5995231201785697655  2.022033e+07
# 4                 ''    5995231201785697655  2.022033e+07
#
#    Number_of_training_instances  Number_of_testing_instances  Number_correct  \
# 0                         135.0                         15.0            15.0
# 1                         135.0                         15.0            15.0
# 2                         135.0                         15.0            15.0
# 3                         135.0                         15.0            15.0
# 4                         135.0                         15.0            14.0
#
#    ...  Serialized_Model_Size  Serialized_Train_Set_Size  \
# 0  ...                 2968.0                    10633.0
# 1  ...                 2968.0                    10633.0
# 2  ...                 2968.0                    10633.0
# 3  ...                 2968.0                    10633.0
# 4  ...                 2968.0                    10633.0
#
#    Serialized_Test_Set_Size  Coverage_of_Test_Cases_By_Regions  \
# 0                    2353.0                         100.000000
# 1                    2353.0                         100.000000
# 2                    2353.0                         100.000000
# 3                    2353.0                         100.000000
# 4                    2353.0                          93.333333
#
#    Size_of_Predicted_Regions  Summary  measureTreeSize  measureNumLeaves  \
# 0                  40.000000        ?                ?                 ?
# 1                  33.333333        ?                ?                 ?
# 2                  37.777778        ?                ?                 ?
# 3                  37.777778        ?                ?                 ?
# 4                  33.333333        ?                ?                 ?
#
#    measureNumRules  measureOutOfBagError
# 0                ?                     ?
# 1                ?                     ?
# 2                ?                     ?
# 3                ?                     ?
# 4                ?                     ?
#
# [5 rows x 71 columns]

# %% [markdown]
# # Drop Useless columns

# %%
useless_cols = ['Date_time','Key_Run','Key_Fold','Key_Scheme_version_ID','Number_of_training_instances','Number_of_testing_instances',
'Number_correct','Number_incorrect','Number_unclassified','Percent_correct','Percent_incorrect','Percent_unclassified','True_positive_rate',
'Num_true_positives','False_positive_rate','Num_false_positives','True_negative_rate','Num_true_negatives','False_negative_rate','Num_false_negatives'
]
for col in useless_cols:
    df = df.drop(col, 1)
df.describe()
# Out:
# C:\Users\benda\AppData\Local\Temp/ipykernel_15084/2424636923.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop(col, 1)
#        Kappa_statistic  Mean_absolute_error  Root_mean_squared_error  \
# count      2000.000000          2000.000000              2000.000000
# mean          0.598672             0.250654                 0.320417
# std           0.446558             0.228565                 0.206946
# min          -1.000000             0.000000                 0.000000
# 25%           0.055646             0.061134                 0.185080
# 50%           0.800000             0.138501                 0.284027
# 75%           1.000000             0.430108                 0.455172
# max           1.000000             1.000000                 1.000000
#
#        Relative_absolute_error  Root_relative_squared_error  SF_prior_entropy  \
# count              2000.000000                  2000.000000       2000.000000
# mean                 61.315531                    73.931268         18.334633
# std                  45.892510                    42.885221         18.844918
# min                   0.000000                     0.000000          0.736966
# 25%                  14.370905                    42.622941          1.372963
# 50%                  57.934837                    79.082754         12.948647
# 75%                  97.000755                   100.746269         28.752749
# max                 250.000000                   250.000000         50.496248
#
#        SF_scheme_entropy  SF_entropy_gain  SF_mean_prior_entropy  \
# count        2000.000000      2000.000000            2000.000000
# mean          279.934125      -261.599492               1.418778
# std          1068.278009      1062.177005               0.546279
# min             0.000000     -8561.727682               0.736966
# 25%             0.744161        -0.263034               0.980313
# 50%             2.055083         0.400154               1.584963
# 75%            19.021890        20.310418               1.708813
# max          8608.208654        36.937711               2.295284
#
#        SF_mean_scheme_entropy  ...  Elapsed_Time_testing  \
# count             2000.000000  ...           2000.000000
# mean                22.996205  ...              0.000266
# std                 96.897885  ...              0.000474
# min                  0.000000  ...              0.000000
# 25%                  0.275121  ...              0.000000
# 50%                  0.842653  ...              0.000000
# 75%                  1.570317  ...              0.001000
# max               1074.000000  ...              0.005000
#
#        UserCPU_Time_training  UserCPU_Time_testing  \
# count            2000.000000           2000.000000
# mean                0.003285              0.000175
# std                 0.009381              0.001312
# min                 0.000000              0.000000
# 25%                 0.000000              0.000000
# 50%                 0.000000              0.000000
# 75%                 0.000000              0.000000
# max                 0.050000              0.010000
#
#        UserCPU_Time_millis_training  UserCPU_Time_millis_testing  \
# count                    2000.00000                  2000.000000
# mean                        3.28500                     0.175000
# std                         9.38098                     1.311577
# min                         0.00000                     0.000000
# 25%                         0.00000                     0.000000
# 50%                         0.00000                     0.000000
# 75%                         0.00000                     0.000000
# max                        50.00000                    10.000000
#
#        Serialized_Model_Size  Serialized_Train_Set_Size  \
# count            2000.000000                2000.000000
# mean            48931.960000                9537.050000
# std            134984.287416                8267.239883
# min              2841.000000                2295.000000
# 25%              4041.000000                2472.750000
# 50%              5863.000000                6605.500000
# 75%             24529.000000               13615.500000
# max            652588.000000               22672.000000
#
#        Serialized_Test_Set_Size  Coverage_of_Test_Cases_By_Regions  \
# count                2000.00000                        2000.000000
# mean                 2415.45000                          95.048831
# std                   942.40167                          12.092203
# min                  1536.00000                           0.000000
# 25%                  1713.75000                          95.454545
# 50%                  2086.00000                         100.000000
# 75%                  2745.75000                         100.000000
# max                  4033.00000                         100.000000
#
#        Size_of_Predicted_Regions
# count                2000.000000
# mean                   63.201694
# std                    32.557905
# min                    15.646259
# 25%                    34.315090
# 50%                    50.000000
# 75%                   100.000000
# max                   100.000000
#
# [8 rows x 43 columns]

# %%
knn = 'weka.classifiers.lazy.IBk'
df['Key_Scheme'] = df.apply(lambda x: 'Ibk'.__add__(x['Key_Scheme_options'].split(' ')[1]) if x['Key_Scheme'] == knn else x['Key_Scheme'], axis = 1)
df = df.drop('Key_Scheme_options',1)
df
# Out:
# C:\Users\benda\AppData\Local\Temp/ipykernel_15084/2351065575.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('Key_Scheme_options',1)
#      Key_Dataset                         Key_Scheme  Kappa_statistic  \
# 0           iris  weka.classifiers.bayes.NaiveBayes              1.0
# 1           iris  weka.classifiers.bayes.NaiveBayes              1.0
# 2           iris  weka.classifiers.bayes.NaiveBayes              1.0
# 3           iris  weka.classifiers.bayes.NaiveBayes              1.0
# 4           iris  weka.classifiers.bayes.NaiveBayes              0.9
# ...          ...                                ...              ...
# 1995     weather                              Ibk10              1.0
# 1996     weather                              Ibk10              1.0
# 1997     weather                              Ibk10              1.0
# 1998     weather                              Ibk10              1.0
# 1999     weather                              Ibk10              1.0
#
#       Mean_absolute_error  Root_mean_squared_error  Relative_absolute_error  \
# 0                0.026613                 0.091233                 5.987988
# 1                0.000738                 0.002476                 0.166072
# 2                0.005598                 0.018740                 1.259442
# 3                0.009145                 0.029272                 2.057530
# 4                0.042490                 0.200961                 9.560342
# ...                   ...                      ...                      ...
# 1995             0.401515                 0.401515               100.378788
# 1996             0.401515                 0.401515               100.378788
# 1997             0.401515                 0.401515               100.378788
# 1998             0.500000                 0.500000               125.000000
# 1999             0.204545                 0.204545                51.136364
#
#       Root_relative_squared_error  SF_prior_entropy  SF_scheme_entropy  \
# 0                       19.353375         23.774438           1.048448
# 1                        0.525341         23.774438           0.024059
# 2                        3.975444         23.774438           0.187659
# 3                        6.209480         23.774438           0.311854
# 4                       42.630160         23.774438           4.422557
# ...                           ...               ...                ...
# 1995                   100.378788          0.736966           0.740613
# 1996                   100.378788          0.736966           0.740613
# 1997                   100.378788          0.736966           0.740613
# 1998                   125.000000          0.736966           1.000000
# 1999                    51.136364          0.736966           0.330149
#
#       SF_entropy_gain  ...  Serialized_Model_Size  Serialized_Train_Set_Size  \
# 0           22.725989  ...                 2968.0                    10633.0
# 1           23.750378  ...                 2968.0                    10633.0
# 2           23.586779  ...                 2968.0                    10633.0
# 3           23.462584  ...                 2968.0                    10633.0
# 4           19.351881  ...                 2968.0                    10633.0
# ...               ...  ...                    ...                        ...
# 1995        -0.003648  ...                 4041.0                     2364.0
# 1996        -0.003648  ...                 4041.0                     2364.0
# 1997        -0.003648  ...                 4041.0                     2364.0
# 1998        -0.263034  ...                 4041.0                     2364.0
# 1999         0.406817  ...                 4041.0                     2364.0
#
#       Serialized_Test_Set_Size  Coverage_of_Test_Cases_By_Regions  \
# 0                       2353.0                         100.000000
# 1                       2353.0                         100.000000
# 2                       2353.0                         100.000000
# 3                       2353.0                         100.000000
# 4                       2353.0                          93.333333
# ...                        ...                                ...
# 1995                    1536.0                         100.000000
# 1996                    1536.0                         100.000000
# 1997                    1536.0                         100.000000
# 1998                    1536.0                         100.000000
# 1999                    1536.0                         100.000000
#
#       Size_of_Predicted_Regions  Summary  measureTreeSize  measureNumLeaves  \
# 0                     40.000000        ?                ?                 ?
# 1                     33.333333        ?                ?                 ?
# 2                     37.777778        ?                ?                 ?
# 3                     37.777778        ?                ?                 ?
# 4                     33.333333        ?                ?                 ?
# ...                         ...      ...              ...               ...
# 1995                 100.000000        ?                ?                 ?
# 1996                 100.000000        ?                ?                 ?
# 1997                 100.000000        ?                ?                 ?
# 1998                 100.000000        ?                ?                 ?
# 1999                 100.000000        ?                ?                 ?
#
#       measureNumRules  measureOutOfBagError
# 0                   ?                     ?
# 1                   ?                     ?
# 2                   ?                     ?
# 3                   ?                     ?
# 4                   ?                     ?
# ...               ...                   ...
# 1995                ?                     ?
# 1996                ?                     ?
# 1997                ?                     ?
# 1998                ?                     ?
# 1999                ?                     ?
#
# [2000 rows x 50 columns]

# %% [markdown]
# # Group Results By Dataset

# %%
df_groupby_datasets = df.groupby(['Key_Dataset','Key_Scheme']).mean()
df_groupby_datasets
# Out:
#                                                       Kappa_statistic  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                       0.478928
#                  Ibk5                                        0.522710
#                  weka.classifiers.bayes.NaiveBayes           0.326449
#                  weka.classifiers.trees.J48                  0.558558
#                  weka.classifiers.trees.RandomForest         0.720794
# iris             Ibk10                                       0.936000
#                  Ibk5                                        0.936000
#                  weka.classifiers.bayes.NaiveBayes           0.933000
#                  weka.classifiers.trees.J48                  0.921000
#                  weka.classifiers.trees.RandomForest         0.920000
# weather          Ibk10                                       0.500000
#                  Ibk5                                        0.600000
#                  weka.classifiers.bayes.NaiveBayes           0.470000
#                  weka.classifiers.trees.J48                  0.500000
#                  weka.classifiers.trees.RandomForest         0.430000
# weather.symbolic Ibk10                                       0.500000
#                  Ibk5                                        0.520000
#                  weka.classifiers.bayes.NaiveBayes           0.400000
#                  weka.classifiers.trees.J48                  0.290000
#                  weka.classifiers.trees.RandomForest         0.510000
#
#                                                       Mean_absolute_error  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                           0.121515
#                  Ibk5                                            0.109661
#                  weka.classifiers.bayes.NaiveBayes               0.154075
#                  weka.classifiers.trees.J48                      0.100291
#                  weka.classifiers.trees.RandomForest             0.099203
# iris             Ibk10                                           0.042285
#                  Ibk5                                            0.039966
#                  weka.classifiers.bayes.NaiveBayes               0.035485
#                  weka.classifiers.trees.J48                      0.043663
#                  weka.classifiers.trees.RandomForest             0.039520
# weather          Ibk10                                           0.452238
#                  Ibk5                                            0.433081
#                  weka.classifiers.bayes.NaiveBayes               0.453690
#                  weka.classifiers.trees.J48                      0.276869
#                  weka.classifiers.trees.RandomForest             0.467419
# weather.symbolic Ibk10                                           0.454049
#                  Ibk5                                            0.425396
#                  weka.classifiers.bayes.NaiveBayes               0.425566
#                  weka.classifiers.trees.J48                      0.428119
#                  weka.classifiers.trees.RandomForest             0.410995
#
#                                                       Root_mean_squared_error  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                               0.257692
#                  Ibk5                                                0.253193
#                  weka.classifiers.bayes.NaiveBayes                   0.336946
#                  weka.classifiers.trees.J48                          0.283456
#                  weka.classifiers.trees.RandomForest                 0.209678
# iris             Ibk10                                               0.120117
#                  Ibk5                                                0.126058
#                  weka.classifiers.bayes.NaiveBayes                   0.127327
#                  weka.classifiers.trees.J48                          0.142889
#                  weka.classifiers.trees.RandomForest                 0.136750
# weather          Ibk10                                               0.466179
#                  Ibk5                                                0.443933
#                  weka.classifiers.bayes.NaiveBayes                   0.477035
#                  weka.classifiers.trees.J48                          0.300585
#                  weka.classifiers.trees.RandomForest                 0.485172
# weather.symbolic Ibk10                                               0.464833
#                  Ibk5                                                0.443056
#                  weka.classifiers.bayes.NaiveBayes                   0.443546
#                  weka.classifiers.trees.J48                          0.462253
#                  weka.classifiers.trees.RandomForest                 0.427640
#
#                                                       Relative_absolute_error  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                              57.383285
#                  Ibk5                                               51.785601
#                  weka.classifiers.bayes.NaiveBayes                  72.784048
#                  weka.classifiers.trees.J48                         47.345504
#                  weka.classifiers.trees.RandomForest                46.850707
# iris             Ibk10                                               9.514023
#                  Ibk5                                                8.992423
#                  weka.classifiers.bayes.NaiveBayes                   7.984167
#                  weka.classifiers.trees.J48                          9.824221
#                  weka.classifiers.trees.RandomForest                 8.892000
# weather          Ibk10                                              96.015772
#                  Ibk5                                               92.153587
#                  weka.classifiers.bayes.NaiveBayes                  96.697771
#                  weka.classifiers.trees.J48                         57.123810
#                  weka.classifiers.trees.RandomForest               100.548801
# weather.symbolic Ibk10                                              96.684329
#                  Ibk5                                               91.105871
#                  weka.classifiers.bayes.NaiveBayes                  91.696839
#                  weka.classifiers.trees.J48                         94.290476
#                  weka.classifiers.trees.RandomForest                88.637377
#
#                                                       Root_relative_squared_error  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                                  79.401689
#                  Ibk5                                                   78.020380
#                  weka.classifiers.bayes.NaiveBayes                     103.852062
#                  weka.classifiers.trees.J48                             87.330035
#                  weka.classifiers.trees.RandomForest                    64.614143
# iris             Ibk10                                                  25.480594
#                  Ibk5                                                   26.740849
#                  weka.classifiers.bayes.NaiveBayes                      27.010188
#                  weka.classifiers.trees.J48                             30.311273
#                  weka.classifiers.trees.RandomForest                    29.009015
# weather          Ibk10                                                  97.176494
#                  Ibk5                                                   92.768454
#                  weka.classifiers.bayes.NaiveBayes                      99.657942
#                  weka.classifiers.trees.J48                             60.554336
#                  weka.classifiers.trees.RandomForest                   102.450197
# weather.symbolic Ibk10                                                  97.235567
#                  Ibk5                                                   93.133191
#                  weka.classifiers.bayes.NaiveBayes                      93.792439
#                  weka.classifiers.trees.J48                             99.548158
#                  weka.classifiers.trees.RandomForest                    90.538361
#
#                                                       SF_prior_entropy  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                       46.811851
#                  Ibk5                                        46.811851
#                  weka.classifiers.bayes.NaiveBayes           46.811851
#                  weka.classifiers.trees.J48                  46.811851
#                  weka.classifiers.trees.RandomForest         46.811851
# iris             Ibk10                                       23.774438
#                  Ibk5                                        23.774438
#                  weka.classifiers.bayes.NaiveBayes           23.774438
#                  weka.classifiers.trees.J48                  23.774438
#                  weka.classifiers.trees.RandomForest         23.774438
# weather          Ibk10                                        1.376122
#                  Ibk5                                         1.376122
#                  weka.classifiers.bayes.NaiveBayes            1.376122
#                  weka.classifiers.trees.J48                   1.376122
#                  weka.classifiers.trees.RandomForest          1.376122
# weather.symbolic Ibk10                                        1.376122
#                  Ibk5                                         1.376122
#                  weka.classifiers.bayes.NaiveBayes            1.376122
#                  weka.classifiers.trees.J48                   1.376122
#                  weka.classifiers.trees.RandomForest          1.376122
#
#                                                       SF_scheme_entropy  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                        31.681190
#                  Ibk5                                         33.396867
#                  weka.classifiers.bayes.NaiveBayes           162.886314
#                  weka.classifiers.trees.J48                 4403.365214
#                  weka.classifiers.trees.RandomForest         135.565604
# iris             Ibk10                                         1.877016
#                  Ibk5                                          2.126262
#                  weka.classifiers.bayes.NaiveBayes             3.014785
#                  weka.classifiers.trees.J48                  485.089338
#                  weka.classifiers.trees.RandomForest          13.390353
# weather          Ibk10                                         1.395615
#                  Ibk5                                          1.329151
#                  weka.classifiers.bayes.NaiveBayes             3.434820
#                  weka.classifiers.trees.J48                   86.777533
#                  weka.classifiers.trees.RandomForest           1.565769
# weather.symbolic Ibk10                                         1.369786
#                  Ibk5                                          1.275498
#                  weka.classifiers.bayes.NaiveBayes             1.389372
#                  weka.classifiers.trees.J48                  226.486097
#                  weka.classifiers.trees.RandomForest           1.265922
#
#                                                       SF_entropy_gain  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                      15.130661
#                  Ibk5                                       13.414984
#                  weka.classifiers.bayes.NaiveBayes        -116.074463
#                  weka.classifiers.trees.J48              -4356.553363
#                  weka.classifiers.trees.RandomForest       -88.753753
# iris             Ibk10                                      21.897421
#                  Ibk5                                       21.648176
#                  weka.classifiers.bayes.NaiveBayes          20.759653
#                  weka.classifiers.trees.J48               -461.314900
#                  weka.classifiers.trees.RandomForest        10.384084
# weather          Ibk10                                      -0.019493
#                  Ibk5                                        0.046971
#                  weka.classifiers.bayes.NaiveBayes          -2.058699
#                  weka.classifiers.trees.J48                -85.401412
#                  weka.classifiers.trees.RandomForest        -0.189648
# weather.symbolic Ibk10                                       0.006336
#                  Ibk5                                        0.100623
#                  weka.classifiers.bayes.NaiveBayes          -0.013251
#                  weka.classifiers.trees.J48               -225.109976
#                  weka.classifiers.trees.RandomForest         0.110200
#
#                                                       SF_mean_prior_entropy  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                             2.187047
#                  Ibk5                                              2.187047
#                  weka.classifiers.bayes.NaiveBayes                 2.187047
#                  weka.classifiers.trees.J48                        2.187047
#                  weka.classifiers.trees.RandomForest               2.187047
# iris             Ibk10                                             1.584963
#                  Ibk5                                              1.584963
#                  weka.classifiers.bayes.NaiveBayes                 1.584963
#                  weka.classifiers.trees.J48                        1.584963
#                  weka.classifiers.trees.RandomForest               1.584963
# weather          Ibk10                                             0.951550
#                  Ibk5                                              0.951550
#                  weka.classifiers.bayes.NaiveBayes                 0.951550
#                  weka.classifiers.trees.J48                        0.951550
#                  weka.classifiers.trees.RandomForest               0.951550
# weather.symbolic Ibk10                                             0.951550
#                  Ibk5                                              0.951550
#                  weka.classifiers.bayes.NaiveBayes                 0.951550
#                  weka.classifiers.trees.J48                        0.951550
#                  weka.classifiers.trees.RandomForest               0.951550
#
#                                                       SF_mean_scheme_entropy  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                              1.479905
#                  Ibk5                                               1.560355
#                  weka.classifiers.bayes.NaiveBayes                  7.646062
#                  weka.classifiers.trees.J48                       205.768858
#                  weka.classifiers.trees.RandomForest                6.300551
# iris             Ibk10                                              0.125134
#                  Ibk5                                               0.141751
#                  weka.classifiers.bayes.NaiveBayes                  0.200986
#                  weka.classifiers.trees.J48                        32.339289
#                  weka.classifiers.trees.RandomForest                0.892690
# weather          Ibk10                                              0.958844
#                  Ibk5                                               0.907804
#                  weka.classifiers.bayes.NaiveBayes                  2.201746
#                  weka.classifiers.trees.J48                        48.918767
#                  weka.classifiers.trees.RandomForest                1.082266
# weather.symbolic Ibk10                                              0.941720
#                  Ibk5                                               0.887272
#                  weka.classifiers.bayes.NaiveBayes                  0.964948
#                  weka.classifiers.trees.J48                       145.713996
#                  weka.classifiers.trees.RandomForest                0.891149
#
#                                                       ...  \
# Key_Dataset      Key_Scheme                           ...
# Glass            Ibk10                                ...
#                  Ibk5                                 ...
#                  weka.classifiers.bayes.NaiveBayes    ...
#                  weka.classifiers.trees.J48           ...
#                  weka.classifiers.trees.RandomForest  ...
# iris             Ibk10                                ...
#                  Ibk5                                 ...
#                  weka.classifiers.bayes.NaiveBayes    ...
#                  weka.classifiers.trees.J48           ...
#                  weka.classifiers.trees.RandomForest  ...
# weather          Ibk10                                ...
#                  Ibk5                                 ...
#                  weka.classifiers.bayes.NaiveBayes    ...
#                  weka.classifiers.trees.J48           ...
#                  weka.classifiers.trees.RandomForest  ...
# weather.symbolic Ibk10                                ...
#                  Ibk5                                 ...
#                  weka.classifiers.bayes.NaiveBayes    ...
#                  weka.classifiers.trees.J48           ...
#                  weka.classifiers.trees.RandomForest  ...
#
#                                                       Elapsed_Time_testing  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                             0.00054
#                  Ibk5                                              0.00069
#                  weka.classifiers.bayes.NaiveBayes                 0.00066
#                  weka.classifiers.trees.J48                        0.00016
#                  weka.classifiers.trees.RandomForest               0.00085
# iris             Ibk10                                             0.00044
#                  Ibk5                                              0.00060
#                  weka.classifiers.bayes.NaiveBayes                 0.00030
#                  weka.classifiers.trees.J48                        0.00010
#                  weka.classifiers.trees.RandomForest               0.00041
# weather          Ibk10                                             0.00006
#                  Ibk5                                              0.00010
#                  weka.classifiers.bayes.NaiveBayes                 0.00004
#                  weka.classifiers.trees.J48                        0.00002
#                  weka.classifiers.trees.RandomForest               0.00005
# weather.symbolic Ibk10                                             0.00004
#                  Ibk5                                              0.00007
#                  weka.classifiers.bayes.NaiveBayes                 0.00007
#                  weka.classifiers.trees.J48                        0.00006
#                  weka.classifiers.trees.RandomForest               0.00005
#
#                                                       UserCPU_Time_training  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                               0.0000
#                  Ibk5                                                0.0000
#                  weka.classifiers.bayes.NaiveBayes                   0.0009
#                  weka.classifiers.trees.J48                          0.0047
#                  weka.classifiers.trees.RandomForest                 0.0401
# iris             Ibk10                                               0.0001
#                  Ibk5                                                0.0002
#                  weka.classifiers.bayes.NaiveBayes                   0.0004
#                  weka.classifiers.trees.J48                          0.0007
#                  weka.classifiers.trees.RandomForest                 0.0135
# weather          Ibk10                                               0.0000
#                  Ibk5                                                0.0000
#                  weka.classifiers.bayes.NaiveBayes                   0.0000
#                  weka.classifiers.trees.J48                          0.0000
#                  weka.classifiers.trees.RandomForest                 0.0021
# weather.symbolic Ibk10                                               0.0000
#                  Ibk5                                                0.0000
#                  weka.classifiers.bayes.NaiveBayes                   0.0001
#                  weka.classifiers.trees.J48                          0.0000
#                  weka.classifiers.trees.RandomForest                 0.0029
#
#                                                       UserCPU_Time_testing  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                              0.0006
#                  Ibk5                                               0.0003
#                  weka.classifiers.bayes.NaiveBayes                  0.0001
#                  weka.classifiers.trees.J48                         0.0002
#                  weka.classifiers.trees.RandomForest                0.0006
# iris             Ibk10                                              0.0005
#                  Ibk5                                               0.0002
#                  weka.classifiers.bayes.NaiveBayes                  0.0002
#                  weka.classifiers.trees.J48                         0.0001
#                  weka.classifiers.trees.RandomForest                0.0006
# weather          Ibk10                                              0.0000
#                  Ibk5                                               0.0001
#                  weka.classifiers.bayes.NaiveBayes                  0.0000
#                  weka.classifiers.trees.J48                         0.0000
#                  weka.classifiers.trees.RandomForest                0.0000
# weather.symbolic Ibk10                                              0.0000
#                  Ibk5                                               0.0000
#                  weka.classifiers.bayes.NaiveBayes                  0.0000
#                  weka.classifiers.trees.J48                         0.0000
#                  weka.classifiers.trees.RandomForest                0.0000
#
#                                                       UserCPU_Time_millis_training  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                                         0.0
#                  Ibk5                                                          0.0
#                  weka.classifiers.bayes.NaiveBayes                             0.9
#                  weka.classifiers.trees.J48                                    4.7
#                  weka.classifiers.trees.RandomForest                          40.1
# iris             Ibk10                                                         0.1
#                  Ibk5                                                          0.2
#                  weka.classifiers.bayes.NaiveBayes                             0.4
#                  weka.classifiers.trees.J48                                    0.7
#                  weka.classifiers.trees.RandomForest                          13.5
# weather          Ibk10                                                         0.0
#                  Ibk5                                                          0.0
#                  weka.classifiers.bayes.NaiveBayes                             0.0
#                  weka.classifiers.trees.J48                                    0.0
#                  weka.classifiers.trees.RandomForest                           2.1
# weather.symbolic Ibk10                                                         0.0
#                  Ibk5                                                          0.0
#                  weka.classifiers.bayes.NaiveBayes                             0.1
#                  weka.classifiers.trees.J48                                    0.0
#                  weka.classifiers.trees.RandomForest                           2.9
#
#                                                       UserCPU_Time_millis_testing  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                                        0.6
#                  Ibk5                                                         0.3
#                  weka.classifiers.bayes.NaiveBayes                            0.1
#                  weka.classifiers.trees.J48                                   0.2
#                  weka.classifiers.trees.RandomForest                          0.6
# iris             Ibk10                                                        0.5
#                  Ibk5                                                         0.2
#                  weka.classifiers.bayes.NaiveBayes                            0.2
#                  weka.classifiers.trees.J48                                   0.1
#                  weka.classifiers.trees.RandomForest                          0.6
# weather          Ibk10                                                        0.0
#                  Ibk5                                                         0.1
#                  weka.classifiers.bayes.NaiveBayes                            0.0
#                  weka.classifiers.trees.J48                                   0.0
#                  weka.classifiers.trees.RandomForest                          0.0
# weather.symbolic Ibk10                                                        0.0
#                  Ibk5                                                         0.0
#                  weka.classifiers.bayes.NaiveBayes                            0.0
#                  weka.classifiers.trees.J48                                   0.0
#                  weka.classifiers.trees.RandomForest                          0.0
#
#                                                       Serialized_Model_Size  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                             24525.40
#                  Ibk5                                              24485.48
#                  weka.classifiers.bayes.NaiveBayes                  6682.00
#                  weka.classifiers.trees.J48                        16140.12
#                  weka.classifiers.trees.RandomForest              627090.89
# iris             Ibk10                                             12318.00
#                  Ibk5                                              12278.24
#                  weka.classifiers.bayes.NaiveBayes                  2968.00
#                  weka.classifiers.trees.J48                         4494.56
#                  weka.classifiers.trees.RandomForest               97376.64
# weather          Ibk10                                              4013.40
#                  Ibk5                                               3973.40
#                  weka.classifiers.bayes.NaiveBayes                  2841.00
#                  weka.classifiers.trees.J48                         4259.08
#                  weka.classifiers.trees.RandomForest               55686.31
# weather.symbolic Ibk10                                              4235.24
#                  Ibk5                                               4200.60
#                  weka.classifiers.bayes.NaiveBayes                  2911.00
#                  weka.classifiers.trees.J48                         4284.26
#                  weka.classifiers.trees.RandomForest               63875.58
#
#                                                       Serialized_Train_Set_Size  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                                  22628.4
#                  Ibk5                                                   22628.4
#                  weka.classifiers.bayes.NaiveBayes                      22628.4
#                  weka.classifiers.trees.J48                             22628.4
#                  weka.classifiers.trees.RandomForest                    22628.4
# iris             Ibk10                                                  10633.0
#                  Ibk5                                                   10633.0
#                  weka.classifiers.bayes.NaiveBayes                      10633.0
#                  weka.classifiers.trees.J48                             10633.0
#                  weka.classifiers.trees.RandomForest                    10633.0
# weather          Ibk10                                                   2336.4
#                  Ibk5                                                    2336.4
#                  weka.classifiers.bayes.NaiveBayes                       2336.4
#                  weka.classifiers.trees.J48                              2336.4
#                  weka.classifiers.trees.RandomForest                     2336.4
# weather.symbolic Ibk10                                                   2550.4
#                  Ibk5                                                    2550.4
#                  weka.classifiers.bayes.NaiveBayes                       2550.4
#                  weka.classifiers.trees.J48                              2550.4
#                  weka.classifiers.trees.RandomForest                     2550.4
#
#                                                       Serialized_Test_Set_Size  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                                  3967.6
#                  Ibk5                                                   3967.6
#                  weka.classifiers.bayes.NaiveBayes                      3967.6
#                  weka.classifiers.trees.J48                             3967.6
#                  weka.classifiers.trees.RandomForest                    3967.6
# iris             Ibk10                                                  2353.0
#                  Ibk5                                                   2353.0
#                  weka.classifiers.bayes.NaiveBayes                      2353.0
#                  weka.classifiers.trees.J48                             2353.0
#                  weka.classifiers.trees.RandomForest                    2353.0
# weather          Ibk10                                                  1563.6
#                  Ibk5                                                   1563.6
#                  weka.classifiers.bayes.NaiveBayes                      1563.6
#                  weka.classifiers.trees.J48                             1563.6
#                  weka.classifiers.trees.RandomForest                    1563.6
# weather.symbolic Ibk10                                                  1777.6
#                  Ibk5                                                   1777.6
#                  weka.classifiers.bayes.NaiveBayes                      1777.6
#                  weka.classifiers.trees.J48                             1777.6
#                  weka.classifiers.trees.RandomForest                    1777.6
#
#                                                       Coverage_of_Test_Cases_By_Regions  \
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                                        94.954545
#                  Ibk5                                                         91.075758
#                  weka.classifiers.bayes.NaiveBayes                            69.670996
#                  weka.classifiers.trees.J48                                   78.543290
#                  weka.classifiers.trees.RandomForest                          98.465368
# iris             Ibk10                                                       100.000000
#                  Ibk5                                                         99.866667
#                  weka.classifiers.bayes.NaiveBayes                            97.733333
#                  weka.classifiers.trees.J48                                   95.933333
#                  weka.classifiers.trees.RandomForest                          98.733333
# weather          Ibk10                                                       100.000000
#                  Ibk5                                                        100.000000
#                  weka.classifiers.bayes.NaiveBayes                            94.000000
#                  weka.classifiers.trees.J48                                   95.500000
#                  weka.classifiers.trees.RandomForest                         100.000000
# weather.symbolic Ibk10                                                       100.000000
#                  Ibk5                                                        100.000000
#                  weka.classifiers.bayes.NaiveBayes                           100.000000
#                  weka.classifiers.trees.J48                                   86.500000
#                  weka.classifiers.trees.RandomForest                         100.000000
#
#                                                       Size_of_Predicted_Regions
# Key_Dataset      Key_Scheme
# Glass            Ibk10                                                34.005566
#                  Ibk5                                                 26.736549
#                  weka.classifiers.bayes.NaiveBayes                    25.880025
#                  weka.classifiers.trees.J48                           21.248299
#                  weka.classifiers.trees.RandomForest                  36.591218
# iris             Ibk10                                                41.222222
#                  Ibk5                                                 38.133333
#                  weka.classifiers.bayes.NaiveBayes                    36.622222
#                  weka.classifiers.trees.J48                           34.622222
#                  weka.classifiers.trees.RandomForest                  37.222222
# weather          Ibk10                                               100.000000
#                  Ibk5                                                100.000000
#                  weka.classifiers.bayes.NaiveBayes                    95.250000
#                  weka.classifiers.trees.J48                           67.500000
#                  weka.classifiers.trees.RandomForest                  99.000000
# weather.symbolic Ibk10                                               100.000000
#                  Ibk5                                                 98.750000
#                  weka.classifiers.bayes.NaiveBayes                   100.000000
#                  weka.classifiers.trees.J48                           72.250000
#                  weka.classifiers.trees.RandomForest                  99.000000
#
# [20 rows x 43 columns]

# %% [markdown]
# # Comparing Models Performance

# %%
algos = df['Key_Scheme'].unique() 
def compare_models(col: str, dataset: str):
    data = []
    for ind in df_groupby_datasets.index:
        if (ind[0] == dataset):
            data.append(df_groupby_datasets.loc[df_groupby_datasets.index == ind, df_groupby_datasets.columns == col].values[0])
    data = [item for sublist in data for item in sublist]
    fig = plt.figure(figsize = (20, 5))
    plt.bar(algos, data)
    plt.xlabel('Algorithm')
    plt.ylabel(col)
    plt.title(f'{dataset.capitalize()} - {col}')

# %%
datasets = ['Glass','iris', 'weather', 'weather.symbolic']
important_cols = ['IR_precision', 'IR_recall', 'F_measure', 'Root_mean_squared_error', 'Elapsed_Time_training', 'Elapsed_Time_testing']
for dataset in datasets:
    for col in important_cols:
        compare_models(col=col, dataset=dataset)
# Out:
# C:\Users\benda\AppData\Local\Temp/ipykernel_15084/1145865436.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize = (20, 5))
